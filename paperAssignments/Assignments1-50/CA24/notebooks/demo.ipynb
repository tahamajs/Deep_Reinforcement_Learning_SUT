# %% [markdown]
# ## Setup
# Make sure to create and activate a virtual environment and install requirements: `pip install -r ../requirements.txt`.

# %% [markdown]
# ## Load Config
# ```python
# from src.config import Config, load_from_yaml
# cfg = load_from_yaml('../configs/default.yaml')
# print(cfg)
# ```
# :
# ,
# : {},
# : [
# ,
# ,
# ,
# ,
# ,

# %% [markdown]
# ## Results
# Plot training loss per epoch (placeholder):
# ```python
# # import matplotlib.pyplot as plt
# # plt.plot([0.5, 0.4, 0.35, 0.33])
# # plt.title('Train Loss')
# # plt.xlabel('Epoch')
# # plt.ylabel('Loss')
# # plt.show()
# ```
# :
# ,
# : {},
# : [
# ,
# ,
# ,
#
# : {
# : {
# :
# 3
# ,
# :
# ,
# :
#
# : {
# :
# ,
# :
# 3.1
#
# : 4,
# : 5
