# %%
from paperAssignments.Assignments1_50.CA17.src.config import get_default_config
from paperAssignments.Assignments1_50.CA17.src.train import train_once

cfg = get_default_config()
# reduce timesteps for quick runs
cfg = type(cfg)(**{**cfg.__dict__, 'total_timesteps': 2000})
train_once(cfg)
