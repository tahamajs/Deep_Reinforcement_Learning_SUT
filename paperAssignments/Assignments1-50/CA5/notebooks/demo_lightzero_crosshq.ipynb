# %% [markdown]
# # CrossHQ + MuZero Adapter MCTS Demo
#
# This notebook runs the `lightzero_run_crosshq.py` planning demo and displays the generated visualizations.

# %%
import sys
from pathlib import Path
repo_root = Path(__file__).parents[2]
sys.path.append(str(repo_root))
from paperAssignments.Assignments1_50.CA5.scripts.lightzero_run_crosshq import run_crosshq_planning
out = run_crosshq_planning(seed=0, sims=100, horizon=3, out_dir='pictures')
print('plots in', out)

# %%
from IPython.display import Image, display
import glob
for p in sorted(glob.glob('pictures/crosshq_root_t*.png')):
    display(Image(p))
