# %% [markdown]
# # CA20 demo
#
# Quick notebook demonstrating the debug training pipeline. This notebook is unexecuted in the repository.

# %%
from paperAssignments.Assignments1_50.CA20.src import train, config

cfg = config.Config()
cfg.epochs = 2
cfg.batch_size = 32

res = train.train(cfg)
print(res)
