# %% [markdown]
# # HW12 — CQL-SAC Reference Solution
#
# This notebook demonstrates the completed implementation for the CQL-SAC exercise (Pendulum).
# It imports the reference solution `answers/solution_cql_sac.py` and shows how to run training and evaluate the agent.
#
# Note: Do not run long trainings inside the repo unless you want to. The default example below runs a short debug training.

# %%
# Import the provided solution module and run a short training run as a smoke test.
from answers.solution_cql_sac import train, Config

# Small debug config (short training)
cfg = Config(
    epochs=2,
    steps_per_epoch=200,
    seed=0,
    device="cpu",
    save_fig="homeworks/HW12_Hierarchical_RL/answers/training_debug.png",
)

# Run training (will save a plot to the answers folder)
# Warning: this will execute training if run; reduce epochs/steps for quick tests.
train(cfg)

# After training you can evaluate or inspect the saved figure at the path above.
