# %% [markdown]
# # HW7 Value-Based Theory — Notebook Stub
#
# This notebook provides a lightweight, reproducible scaffold for HW7 (theoretical). It centralizes imports, seeds, and run metadata; no heavy computation is expected.
#
# **Sections**
#
# 1. Setup & seeds
# 2. Data/inputs (theoretical assignment)
# 3. Solution references
# 4. Run metadata capture
# 5. Evaluation/next steps

# %%
import json
import os
import platform
import random
import subprocess
from datetime import datetime

import numpy as np
import torch


def set_seed(seed: int = 0) -> None:
    """Set seeds for reproducibility across random, numpy, and torch."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


def get_commit_hash(default: str = "UNKNOWN") -> str:
    try:
        return subprocess.check_output(["git", "rev-parse", "HEAD"], text=True).strip()
    except Exception:
        return default


SEED = 0
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

set_seed(SEED)

print(f"Seed: {SEED} | Device: {DEVICE} | torch={torch.__version__}")
# Out:
# Seed: 0 | Device: cpu | torch=2.9.1

# %% [markdown]
# ## Data / Inputs
#
# This assignment is purely theoretical. No datasets are loaded. All answers reside in Markdown (`../HW7_Complete_Solutions.md`) and are imported into the LaTeX report.

# %% [markdown]
# ## Solution References
#
# - Primary answers: `../HW7_Complete_Solutions.md`
# - LaTeX report: `../Homework-7-Template/template.tex` (imports the Markdown via `\markdownInput`) → output `../reports/Homework-7-Report.pdf` when built.
# - Description/questions: `../reports/HW7_Questions.pdf`.

# %%
run_info = {
    "assignment": "HW7 Value-Based Theory",
    "seed": SEED,
    "device": DEVICE,
    "torch_version": torch.__version__,
    "numpy_version": np.__version__,
    "python_version": platform.python_version(),
    "timestamp": datetime.utcnow().isoformat() + "Z",
    "commit": get_commit_hash(),
    "notes": "Theoretical-only; see HW7_Complete_Solutions.md and reports/Homework-7-Report.pdf.",
}

os.makedirs("../reports", exist_ok=True)
with open("../reports/run_info.json", "w", encoding="utf-8") as f:
    json.dump(run_info, f, indent=2)

print("Saved run metadata to ../reports/run_info.json")
# Out:
# Saved run metadata to ../reports/run_info.json
# /var/folders/cg/l2rdx46d6lv3b5xc17b420yc0000gn/T/ipykernel_86251/3178538389.py:8: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat() + "Z",

# %% [markdown]
# ## Evaluation / Next Steps
#
# - This notebook does not execute training. Run the metadata cell to log environment details if needed.
# - Render the LaTeX report (`Homework-7-Template/template.tex`) to `reports/Homework-7-Report.pdf` after any solution edits.
# - If you add computations in the future, keep them lightweight and retain the seed/config cell at the top.

# %% [markdown]
# # Notes
#
# - Run the metadata cell (saves `../reports/run_info.json`).
# - To build the LaTeX report: change directory to `Homework-7-Template` and run:
#
#   ```bash
#   pdflatex -output-directory ../reports template.tex
#   ```
#
#   (Requires a local LaTeX installation.)
#
# - Primary solutions are in `HW7_Complete_Solutions.md` and are imported by the LaTeX template.
# - This notebook is intentionally lightweight and import-safe; no training is executed on import.
